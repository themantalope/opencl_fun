# %%
import os
import pandas as pd

# %%
data_file = os.path.join('..' , 'data', 'test_db.hdf5')

# %%
store = pd.HDFStore(data_file)

# %%
store.keys()
# Out:
# ['/', '/table']

# %%
for x in store.iteritems():
    print(x)

# %%
x.count

# %%
x.index

# %%
x = store.items

# %%
x = store.iteritems()

# %%
type(x)

# %%
z = next(x)

# %%
type(z)

# %%
z[0]

# %%
z[1]

# %%
store.get_node('table')

# %%
z=store.get_storer('table')

# %%
type(z)

# %%
z.ndim

# %%
z.nrows

# %%
z.ncols

# %%
x = store.select('table',start=0, stop=10)

# %%
x

# %%
idx = store.select_as_coordinates('table')

# %%
from sklearn.model_selection import train_test_split

# %%
len(idx)

# %%
coord = store.select_as_coordinates('table', where=['index<100','index>=5'])

# %%
coord
# Out:
# Int64Index([ 1646,  1659,  4885,  5068,  5433,  7212,  7297, 10534, 11715,
#             12531, 13120, 14957, 15085, 15616, 17593, 17610, 19192, 20157,
#             20998, 21302, 22048, 22793, 23835, 24436, 26306, 26806, 28753,
#             29838, 29996, 32976, 33033, 33951, 35739, 39823, 41062, 42115,
#             43097, 44012, 45045, 45795, 45881, 46692, 46718, 47569, 48763,
#             49501, 53265, 53937, 56146, 56174, 57609, 59599, 60265, 60715,
#             61020, 61264, 62737, 63184, 64424, 64559, 64936, 65577, 65766,
#             67151, 69145, 70366, 71848, 72234, 73030, 73569, 76114, 76455,
#             77723, 77887, 80652, 81016, 82037, 83040, 83775, 85722, 86208,
#             87253, 87561, 87655, 88120, 89049, 89967, 92416, 93175, 95175,
#             97077, 97141, 98294, 98882, 99754],
#            dtype='int64')

# %%
store.select('table', start=0, stop=100)
# Out:
#              x0        x1         x2        x3         x4    y
# 41451  0.930719  1.483114   9.921945  4.495758  -6.904161  0.0
# 96042  0.185158 -1.422337   7.455091  6.651536  -5.281940  1.0
# 54423  0.630818 -2.957815  11.540971  6.476543  -4.810598  1.0
# 98326  0.321766 -3.277804  13.320971  6.860556  -3.955484  1.0
# 20750  1.150190  3.973161  10.631606  4.423136 -11.855059  0.0
# 42561  0.881955  0.544743   9.182752  4.481009  -7.968243  0.0
# 42514  0.986353  1.060733   9.751927  4.643215 -13.068485  0.0
# 54368  0.375455 -6.202553  16.200148  6.995451  -4.530469  1.0
# 71894  0.583342 -4.532549   9.348172  6.466766  -6.285659  1.0
# 7892   1.258288  2.414893  12.614124  4.682827 -11.628559  0.0
# 25565  0.897587  2.207758  13.212494  4.466858 -10.498590  0.0
# 338    0.952933  0.830598  10.519262  4.506428 -12.379004  0.0
# 89339  0.717122 -1.084460  11.581182  6.532596  -6.307700  1.0
# 53273  0.295415 -5.356339   8.223382  6.785769  -5.927636  1.0
# ...
